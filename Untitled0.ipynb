# %% [markdown]
# <a href="https://colab.research.google.com/github/EdgarPinto01/htmlpersonalfile/blob/master/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# NUMBER GUESSING GAME

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt

def number_guessing_game():
    # Generate a random number between 1 and 100
    target_number = random.randint(1, 100)

    attempts = 0
    history = []

    while True:
        # Get user's guess
        user_guess = int(input("Guess a number between 1 and 100: "))

        # Increment attempts
        attempts += 1

        if user_guess < target_number:
            print("Too low! Try again.")
        elif user_guess > target_number:
            print("Too high! Try again.")
        else:
            print(f"Congratulations! You guessed the number {target_number} in {attempts} attempts.")
            history.append({'Guess': user_guess, 'Attempts': attempts})
            break

    # Create a pandas DataFrame from the history
    df = pd.DataFrame(history)

    # Plot a graph of attempts over time
    plt.plot(df['Attempts'], df['Guess'], marker='o')
    plt.title('Number Guessing Game')
    plt.xlabel('Attempts')
    plt.ylabel('Guess')
    plt.show()

if __name__ == "__main__":
    number_guessing_game()
# Out:
# Guess a number between 1 and 100: 45
# Too high! Try again.
# Guess a number between 1 and 100: 25
# Too high! Try again.
# Guess a number between 1 and 100: 10
# Too low! Try again.
# Guess a number between 1 and 100: 15
# Too high! Try again.
# Guess a number between 1 and 100: 13
# Congratulations! You guessed the number 13 in 5 attempts.
